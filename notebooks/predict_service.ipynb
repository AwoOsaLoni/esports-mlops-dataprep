# %%
import pandas as pd
import joblib # Para cargar el modelo guardado

def predict_player_revenue(new_data):
    # 1. Cargar el modelo que entrenaste previamente
    # (Asegúrate de haber guardado tu modelo con joblib.dump en el paso anterior)
    model = joblib.load('models/random_forest_esports.pkl')

    # 2. Realizar la predicción
    prediction = model.predict(new_data)
    return prediction

if __name__ == "__main__":
    print("Servicio de Predicción de eSports Iniciado...")
    print("Esperando datos de entrada...")
# Out:
# Servicio de Predicción de eSports Iniciado...
# Esperando datos de entrada...
